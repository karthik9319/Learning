# %% [markdown]
# # statistics

# %%
average - typical or middle - central tendency

# %%
arithmetic mean = (sum of all samples)/ (no of samples)

# %%
median = middle one of ordered samples
           - even = mean of middle nums
           - odd  = middle num

# %%
mode = single most common num
     = no repetition then no mode

# %% [markdown]
# variability

# %%
range = max- min = variablility
if diff is more then more variability or less than less variablity

# %%
mean absoulute deviation (mad) = 1/n |(x_avg - x_i)|

# %%
variance (s^2) =  1/n (x_avg - x_i)^2

# %%
standard deviation = square_root(s) = square_root(1/n (x_avg-x_i)^2)

# %%
coefficient of variation =
